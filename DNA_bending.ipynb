# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
PolyAT_Dissociated=np.loadtxt('/home/angelica/Datos/DNA_VWF/MD_atomistic/DNA-VWF_Association/DNAPolyAT_vWF_DAFT/PolyAT_DNA/analysis/bundle/no-associated/bun_kink.xvg', comments=('#', '@'))
PolyAT_Associated=np.loadtxt('/home/angelica/Datos/DNA_VWF/MD_atomistic/DNA-VWF_Association/DNAPolyAT_vWF_DAFT/PolyAT_DNA/analysis/bundle/associated_DNA/bun_kink.xvg', comments=('#', '@'))

ARC1772_Dissociated=np.loadtxt('/home/angelica/Datos/DNA_VWF/MD_atomistic/DNA-VWF_Association/DNA-VWF-DAFT/DNA-VWF-ASSOC/analysis/bundle/no-associated/bun_kink.xvg', comments=('#', '@'))
ARC1772_Associated=np.loadtxt('/home/angelica/Datos/DNA_VWF/MD_atomistic/DNA-VWF_Association/DNA-VWF-DAFT/DNA-VWF-ASSOC/analysis/bundle/associated/bun_kink.xvg', comments=('#','@'))

# %%
#plt.hist(PolyAT_Dissociated[:,1], 100, density=True, alpha=0.5, label='PolyAT unbound')
#plt.hist(PolyAT_Associated[:,1], 100, density=True, color='g', alpha=0.5, label='PolyAT bound')
plt.hist(ARC1772_Dissociated[:,1], 100, density=True, color='red', alpha=0.5, label='ARC1772 unbound')
plt.hist(ARC1772_Associated[:,1], 100, density=True, color='yellow', alpha=0.5, label='ARC1772 bound')
plt.legend()
plt.show()

# %%
plt.hist(PolyAT_Dissociated[:,1], 100, density=True, alpha=0.5, label='PolyAT unbound')
plt.hist(PolyAT_Associated[:,1], 100, density=True, color='g', alpha=0.5, label='PolyAT bound')
#plt.hist(ARC1772_Dissociated[:,1], 100, density=True, color='red', alpha=0.5, label='ARC1772 unbound')
#plt.hist(ARC1772_Associated[:,1], 100, density=True, color='yellow', alpha=0.5, label='ARC1772 bound')
plt.legend()
plt.show()

# %%
plt.plot(PolyAT_Associated[:,0], PolyAT_Associated[:,1], label='PolyAT bound')
plt.plot(PolyAT_Dissociated[:,0],PolyAT_Dissociated[:,1], label='PolyAT unbound')
plt.legend()
plt.show()

# %%
plt.plot(ARC1772_Associated[:,0], ARC1772_Associated[:,1], label='ARC1772 bound')
plt.plot(ARC1772_Dissociated[:,0],ARC1772_Dissociated[:,1], label='ARC1772 unbound')
plt.legend()
plt.show()
